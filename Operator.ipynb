# %% [markdown]
# # Operator

# %% [markdown]
# # Arithmetic operator

# %%
x1, y1 = 10, 5

# %%
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %% [markdown]
# # Assignment operator

# %%
x = 2
x
# Out:
# 2

# %%
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x -= 2
x
# Out:
# 4

# %%
x *= 2
x
# Out:
# 8

# %%
x * = 2
x
# Out:
#   Cell In[14], line 1
#     x * = 2
#         ^
# SyntaxError: invalid syntax

# %%
x //= 2
x
# Out:
# 4

# %%
x /= 2
x
# Out:
# 2.0

# %%
x = 11
x
# Out:
# 11

# %%
x %= 2
x
# Out:
# 1

# %% [markdown]
# # Unary operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -n # Negation
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %% [markdown]
# # Relational operator

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
b < a
# Out:
# False

# %%
a == b
# Out:
# False

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
a = b

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
c = 6
d = 8

# %%
c == d
# Out:
# False

# %%
c > d
# Out:
# False

# %%
c < d
# Out:
# True

# %%
c >= d
# Out:
# False

# %%
c <= d
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
a = 5
b = 6

# %%
a < 8 and b < 5
# Out:
# False

# %%
a < 8 or b < 5
# Out:
# True

# %%
a < 8 or b > 5
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
a < 8 and b < 2
# Out:
# False

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = True 
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
1 and 1
# Out:
# 1

# %%
1 and 0
# Out:
# 0

# %%
0 and 1
# Out:
# 0

# %%
0 and 0
# Out:
# 0

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
1 or 1
# Out:
# 1

# %%
1 or 0
# Out:
# 1

# %%
0 or 1
# Out:
# 1

# %%
0 or 0
# Out:
# 0

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
