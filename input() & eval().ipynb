# %% [markdown]
# # input() & eval()

# %%
name = input('Ente your name')
print(name)
# Out:
# Ente your name Rushikesh Sangar
# Rushikesh Sangar

# %%
age = int(input('Enter your age'))
print(age)
# Out:
# Enter your age 29
# 29

# %%
price = float(input('Enter petrol price'))
print(price)
# Out:
# Enter petrol price 110.10
# 110.1

# %%
st = input('Enter a string')[0]
print(st)
# Out:
# Enter a string Rushikesh
# R

# %%
st = input('Enter a string')[3:10]
print(st)
# Out:
# Enter a string Welcometonareshit
# cometon

# %%
exp = input('Enter a value')
print(exp)
# Out:
# Enter a value 2 + 3 - 1 + 10
# 2 + 3 - 1 + 10

# %%
exp1 = int(input('Enter a value'))
print(exp1)
# Out:
# Enter a value 2 + 3 - 1 + 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 exp1 = int(input('Enter a value'))
#       2 print(exp1)
#
# ValueError: invalid literal for int() with base 10: '2 + 3 - 1 + 10'

# %%
exp2 = eval(input('Enter a value'))
print(exp2)
# Out:
# Enter a value 2 + 3 - 1 + 10
# 14

# %%
exp3 = eval(input('Enter a value'))
print(exp3)
# Out:
# Enter a value 3 * 5 + 9 - 3
# 21

# %%
a = 10
b = 20
result = eval('a * b + 10 - 5')
print(result)
# Out:
# 205
