# %% [markdown]
# # Module & input()

# %% [markdown]
# # Math module

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
x = round(math.sqrt(25))
x
# Out:
# 5

# %%
math.ceil(3.8)
# Out:
# 4

# %%
math.floor(3.8)
# Out:
# 3

# %%
pow(2, 3)
# Out:
# 8

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi = 3.17
pi
# Out:
# 3.17

# %%
# help()  It gives all help options

# %%
m.sqrt(49)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m.sqrt(49)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import sqrt, pow # Multiple functions at a time
print(pow(3, 2))
print(m.sqrt(10))
# Out:
# 9.0
# 3.1622776601683795

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # input()

# %%
input()
# Out:
#  Hello
# 'Hello'

# %%
input()
input()
# Out:
#  Hello
#  Hi
# 'Hi'

# %%
x = input()
y = input()
z = x + y
print(z)
# Out:
#  3
#  2
# 32

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = int(input())
y = int(input())
z = x + y
print(z)
# Out:
#  3
#  2
# 5

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1 = input('Enter the first number')
y1 = input('Enter the second number')
z1 = x1 + y1
print(z1)
# Out:
# Enter the first number 10
# Enter the second number 20
# 1020

# %%
x1 = int(input('Enter the first number'))
y1 = int(input('Enter the second number'))
z1 = x1 + y1
print(z1)
# Out:
# Enter the first number 10
# Enter the second number 20
# 30

# %%
x2 = input('Enter username')
y2 = input('Enter password')
z2 = x2 + y2
print(z2)
# Out:
# Enter username Rushikesh
# Enter password  Sangar
# Rushikesh Sangar

# %%
st = input('Enter a string')
print(st)
# Out:
# Enter a string Hello
# Hello

# %%
st = input('Enter a string')[0]
print(st)
# Out:
# Enter a string Hello
# H

# %%
st = input('Enter a string')[0:2]
print(st)
# Out:
# Enter a string Hello
# He

# %%
st = input('Enter a string')[9:12]
print(st)
# Out:
# Enter a string Welcometonareshit
# nar
