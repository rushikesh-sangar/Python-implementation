# %% [markdown]
# # Data type

# %% [markdown]
# # Python data type
#
# 1) int = Value without decimal.
# 2) float = Value with decimal and only e or E letter is allowed.
# 3) complex = a + bj || a is real and b is imaginary.
# 4) bool = True or False.
# 5) string = Always declare with ' ' || " " || ''' ''' (''' ''' we use for multiline comments).
# 6) Indexing is allowed with strings.

# %%
i = 7
i
# Out:
# 7

# %%
type(i)
# Out:
# int

# %%
1i = 8
1i
# Out:
#   Cell In[3], line 1
#     1i = 8
#     ^
# SyntaxError: invalid decimal literal

# %%
i1 = 8
i1
# Out:
# 8

# %%
i + i1
# Out:
# 15

# %%
f = 110.10
f
# Out:
# 110.1

# %%
type(f)
# Out:
# float

# %%
f2 = 1e0
f2
# Out:
# 1.0

# %%
f3 = 1t0
f3
# Out:
#   Cell In[9], line 1
#     f3 = 1t0
#          ^
# SyntaxError: invalid decimal literal

# %%
f3 = 1e1
f3
# Out:
# 10.0

# %%
f4 = 2e2
f4
# Out:
# 200.0

# %%
f5 = 3E3
f5
# Out:
# 3000.0

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b = False
b
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - True
# Out:
# 0

# %%
True * True
# Out:
# 1

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
True + False - False
# Out:
# 1

# %%
c = 1 + 2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
d = 2 + 3j
d
# Out:
# (2+3j)

# %%
c + d
# Out:
# (3+5j)

# %%
c
# Out:
# (1+2j)

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
d
# Out:
# (2+3j)

# %%
d.real
# Out:
# 2.0

# %%
d.imag
# Out:
# 3.0

# %%
s = 'nit'
s
# Out:
# 'nit'

# %%
type(s)
# Out:
# str

# %%
s2 = "nit"
s2
# Out:
# 'nit'

# %%
s3 = 'Nit
         Welcome 
                New batch gen ai & agentic ai'
s3
# Out:
#   Cell In[36], line 1
#     s3 = 'Nit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = "Nit
         Welcome
                New batch gen ai & agentic ai"
s4
# Out:
#   Cell In[37], line 1
#     s4 = "Nit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s5 = '''Nit
           Welcome
                  New batch gen ai & agentic ai'''
s5
# Out:
# 'Nit\n           Welcome\n                  New batch gen ai & agentic ai'

# %%
s
# Out:
# 'nit'

# %%
s[0]
# Out:
# 'n'

# %%
s[1]
# Out:
# 'i'

# %%
s[2]
# Out:
# 't'

# %%
print(s[0])
print(s[1])
print(s[2])
# Out:
# n
# i
# t

# %%
len(s)
# Out:
# 3

# %%
s6 = 'Welcome'
s6
# Out:
# 'Welcome'

# %%
s6[:]
# Out:
# 'Welcome'

# %%
s6[1:4] # Forward slicing
# Out:
# 'elc'

# %%
s6
# Out:
# 'Welcome'

# %%
s7 = 'Nareshtechnology'
s7
# Out:
# 'Nareshtechnology'

# %%
s7[:]
# Out:
# 'Nareshtechnology'

# %%
len(s7)
# Out:
# 16

# %%
s7
# Out:
# 'Nareshtechnology'

# %%
s7[0:]
# Out:
# 'Nareshtechnology'

# %%
s7
# Out:
# 'Nareshtechnology'

# %%
s7[:6]
# Out:
# 'Naresh'

# %%
s7
# Out:
# 'Nareshtechnology'

# %%
s7[:3]
# Out:
# 'Nar'

# %%
s7
# Out:
# 'Nareshtechnology'

# %%
s7[:]
# Out:
# 'Nareshtechnology'

# %%
s8 = 'Welcometeam'
s8
# Out:
# 'Welcometeam'

# %%
s8[1:5]
# Out:
# 'elco'

# %%
s8[1:8:3]
# Out:
# 'eot'

# %%
s8
# Out:
# 'Welcometeam'

# %%
s8[::1]
# Out:
# 'Welcometeam'

# %%
s8[::2]
# Out:
# 'Wloeem'

# %%
s8[::3]
# Out:
# 'Wcea'

# %%
s8
# Out:
# 'Welcometeam'

# %%
s8[::-1]
# Out:
# 'maetemocleW'

# %%
s8[::-2]
# Out:
# 'meeolW'

# %%
int.__add__(2, 3) # Python magic methods
# Out:
# 5

# %%
int.__sub__(2, 3)
# Out:
# -1

# %%
int.__mul__(2, 3)
# Out:
# 6
