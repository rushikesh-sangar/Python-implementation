# %%
'WELCOM TO NARESHIT'
# Out:
# 'WELCOM TO NARESHIT'

# %%
'WELCOM TO NARESHIT
# Out:
#   File "/tmp/ipython-input-4092513948.py", line 1
#     'WELCOM TO NARESHIT
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'WELCOM TO NARESHIT"
# Out:
#   File "/tmp/ipython-input-317434360.py", line 1
#     'WELCOM TO NARESHIT"
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
2 + 3
# Out:
# 5

# %%
(2+3)-5
# Out:
# 0

# %%
2+3-5
# Out:
# 0

# %%
2+(3-5)
# Out:
# 0

# %%
10 + 2
# Out:
# 12

# %%
10 - 2
# Out:
# 8

# %%
10 * 2
# Out:
# 20

# %%
10 ** 2
# Out:
# 100

# %%
10 / 2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
10 % 2
# Out:
# 0

# %%
11%2
# Out:
# 1

# %%
def greet():
  print('good night')
greet()
# Out:
# good night

# %%
def greet():
  print('good night')
  print('good night')
  print('good night')
  print('good night')
  print('good night')
greet()
# Out:
# good night
# good night
# good night
# good night
# good night

# %%
def greet():
  print('good night')
greet()

greet()

greet()

greet()

greet()
# Out:
# good night
# good night
# good night
# good night
# good night

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('Numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('Numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
plt.ylabel('Numbers')
plt.show()
