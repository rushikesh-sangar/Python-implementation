# %% [markdown]
# # IMDb movie rating analysis

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'D:\Full Stack Data Science With Gen AI & Agentic AI Notes\Notes\April\9 April\Dataset\Movie.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(type(movies))
# Out:
# <class 'pandas.DataFrame'>

# %%
tags = pd.read_csv(r'D:\Full Stack Data Science With Gen AI & Agentic AI Notes\Notes\April\9 April\Dataset\Tag.csv')

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
print(type(tags))
# Out:
# <class 'pandas.DataFrame'>

# %%
ratings = pd.read_csv(r'D:\Full Stack Data Science With Gen AI & Agentic AI Notes\Notes\April\9 April\Dataset\Rating.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
print(type(ratings))
# Out:
# <class 'pandas.DataFrame'>

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
row_0 = tags.iloc[0]
print(type(row_0))
# Out:
# <class 'pandas.Series'>

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
print(row_0['userId'])
# Out:
# 18

# %%
'rating' in row_0
# Out:
# False

# %%
row_0.name
# Out:
# 0

# %%
row_0 = row_0.rename('firstRow')

# %%
row_0.name
# Out:
# 'firstRow'

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
tags.iloc[[0, 11, 500]]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
print(ratings['rating'].mean())
# Out:
# 3.5255285642993797

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10
print(filter1)
print(filter1.any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
filter2 = ratings['rating'] > 0
print(filter2)
print(filter2.all())
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 20000258    True
# 20000259    True
# 20000260    True
# 20000261    True
# 20000262    True
# Name: rating, Length: 20000263, dtype: bool
# True

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (27278, 3)

# %%
print(movies.isnull().any().any()) # No NULL values
# Out:
# False

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
print(ratings.isnull().any().any()) # No NULL values
# Out:
# False

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.shape
# Out:
# (465564, 3)

# %%
print(tags.isnull().any().any()) # We have some tags which are NULL
# Out:
# True

# %%
tags = tags.dropna()

# %%
print(tags.isnull().any().any()) # No NULL values
# Out:
# False

# %%
tags.shape # Number of rows reduced
# Out:
# (465548, 3)

# %%
# %matplotlib inline

# %%
ratings.hist(column = 'rating', figsize = (10, 5))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column = 'rating', figsize = (10, 5))
# Out:
# <Axes: >

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: str

# %%
movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# Roland Joff̩                                                           1
# Seu Jorge                                                               1
# Michel Audiard                                                          1
# French film                                                             1
# Clouseau                                                                1
# Disguises                                                               1
# retarted                                                                1
# circle k                                                                1
# This movie should have been called \\"How Cocaine Ruined Disney\"\""    1
# topless scene                                                           1
# Name: count, dtype: int64

# %%
tag_counts[:10]
# Out:
# tag
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# surreal            2427
# BD-R               2334
# twist ending       2323
# funny              2072
# dystopia           1991
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind = 'bar', figsize = (10, 5))
# Out:
# <Axes: xlabel='tag'>
